# %%
# %pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.10.0-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 86 kB/s  eta 0:00:01
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 479 kB/s eta 0:00:01
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 21 kB/s  eta 0:00:01
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.27.0->tweepy) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.27.0->tweepy) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.27.0->tweepy) (2.8)
# Installing collected packages: oauthlib, charset-normalizer, requests, requests-oauthlib, tweepy
# Successfully installed charset-normalizer-2.1.0 oauthlib-3.2.0 requests-2.28.1 requests-oauthlib-1.3.1 tweepy-4.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 244 kB/s eta 0:00:01
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 234 kB/s ta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/nihar/.local/lib/python3.8/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.3.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 23 kB/s  eta 0:00:01
# Requirement already satisfied: requests in /home/nihar/.local/lib/python3.8/site-packages (from transformers) (2.28.1)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.8.17-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (768 kB)
#      |████████████████████████████████| 768 kB 331 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /home/nihar/.local/lib/python3.8/site-packages (from transformers) (1.23.2)
# Requirement already satisfied: filelock in /home/nihar/.local/lib/python3.8/site-packages (from transformers) (3.8.0)
# Collecting tqdm>=4.27
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 123 kB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/nihar/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/nihar/.local/lib/python3.8/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/nihar/.local/lib/python3.8/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers) (1.25.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers) (2019.11.28)
# Installing collected packages: tqdm, huggingface-hub, tokenizers, regex, transformers
# Successfully installed huggingface-hub-0.8.1 regex-2022.8.17 tokenizers-0.12.1 tqdm-4.64.0 transformers-4.21.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/nihar/.local/lib/python3.8/site-packages (1.12.0)
# Requirement already satisfied: tzlocal>=1.1 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (4.2)
# Requirement already satisfied: python-dateutil in /usr/lib/python3/dist-packages (from streamlit) (2.7.3)
# Requirement already satisfied: validators>=0.2 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: pyarrow>=4.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (2.1.9)
# Requirement already satisfied: requests>=2.4 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (4.12.0)
# Requirement already satisfied: pympler>=0.9 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: blinker>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: packaging>=14.1 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (21.3)
# Requirement already satisfied: gitpython!=3.1.19 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: tornado>=5.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (6.2)
# Requirement already satisfied: toml in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from streamlit) (7.0.0)
# Requirement already satisfied: altair>=3.2.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: cachetools>=4.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: numpy in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (1.23.2)
# Requirement already satisfied: click>=7.0 in /usr/lib/python3/dist-packages (from streamlit) (7.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (3.20.1)
# Requirement already satisfied: pandas>=0.21.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (1.4.3)
# Requirement already satisfied: rich>=10.11.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (12.5.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: semver in /home/nihar/.local/lib/python3.8/site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: backports.zoneinfo; python_version < "3.9" in /home/nihar/.local/lib/python3.8/site-packages (from tzlocal>=1.1->streamlit) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /home/nihar/.local/lib/python3.8/site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /home/nihar/.local/lib/python3.8/site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.4->streamlit) (2.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/nihar/.local/lib/python3.8/site-packages (from requests>=2.4->streamlit) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.4->streamlit) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.4->streamlit) (2019.11.28)
# Requirement already satisfied: zipp>=0.5 in /home/nihar/.local/lib/python3.8/site-packages (from importlib-metadata>=1.4->streamlit) (3.8.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /home/nihar/.local/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (6.15.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/nihar/.local/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (8.0.1)
# Requirement already satisfied: traitlets>=4.3.2 in /home/nihar/.local/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.0)
# Requirement already satisfied: jinja2>=2.10.1 in /home/nihar/.local/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (3.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/nihar/.local/lib/python3.8/site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/nihar/.local/lib/python3.8/site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: jsonschema>=3.0 in /home/nihar/.local/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (4.13.0)
# Requirement already satisfied: toolz in /home/nihar/.local/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/lib/python3/dist-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: pytz>=2020.1 in /home/nihar/.local/lib/python3.8/site-packages (from pandas>=0.21.0->streamlit) (2022.2.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/nihar/.local/lib/python3.8/site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/nihar/.local/lib/python3.8/site-packages (from rich>=10.11.0->streamlit) (2.13.0)
# Requirement already satisfied: tzdata; python_version >= "3.6" in /home/nihar/.local/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit) (2022.2)
# Requirement already satisfied: pyzmq>=17 in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (23.2.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (1.6.3)
# Requirement already satisfied: psutil in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (7.3.4)
# Requirement already satisfied: ipython>=7.23.1 in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (8.4.0)
# Requirement already satisfied: nest-asyncio in /home/nihar/.local/lib/python3.8/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (1.5.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/nihar/.local/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.0.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/nihar/.local/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nihar/.local/lib/python3.8/site-packages (from jinja2>=2.10.1->pydeck>=0.1.dev5->streamlit) (2.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/nihar/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/nihar/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/nihar/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/nihar/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /home/nihar/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.3.10)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/nihar/.local/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.11.1)
# Requirement already satisfied: jedi>=0.16 in /home/nihar/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.6.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/nihar/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (3.0.30)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (45.2.0)
# Requirement already satisfied: pickleshare in /home/nihar/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: backcall in /home/nihar/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: stack-data in /home/nihar/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/nihar/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: wcwidth in /home/nihar/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: asttokens in /home/nihar/.local/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.0.8)
# Requirement already satisfied: executing in /home/nihar/.local/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.10.0)
# Requirement already satisfied: pure-eval in /home/nihar/.local/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from asttokens->stack-data->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/nihar/.local/lib/python3.8/site-packages (1.4.3)
# Collecting python-dateutil>=2.8.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 589 kB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /home/nihar/.local/lib/python3.8/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /home/nihar/.local/lib/python3.8/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.14.0)
# Installing collected packages: python-dateutil
# Successfully installed python-dateutil-2.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy as tw
import streamlit as st
import pandas as pd
from transformers import pipeline
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# Creating connection between app and twitter

# %%
consumer_key = 'v3flA8wrDiLaRkXwiN6I9QoLN'
consumer_secret = 'Os6nmO62EfVPcWDrK0JmQvWYYIDAf5lNqaYKEtBSdCHHpwcadB'
access_token = '1269160779904806920-pigIL0WP9uFjQ43cImncVwkANllPVs'
access_token_secret = 'pArVvx871PSq4dhvDHvXOECojRwkpovaoUPYYgTmLWlU9'
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True)

# %%
# %pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 3.6 kB/s eta 0:00:01��████████              | 287.5 MB 295 kB/s eta 0:12:40   | 312.3 MB 105 kB/s eta 0:31:37   | 315.2 MB 162 kB/s eta 0:20:09�█████████           | 335.1 MB 124 kB/s eta 0:23:40MB 599 kB/s eta 0:04:10MB 114 kB/s eta 0:21:41██████        | 385.4 MB 195 kB/s eta 0:10:48��█████████    | 448.2 MB 158 kB/s eta 0:06:41��███████████████████▎   | 452.5 MB 308 kB/s eta 0:03:13███████▌| 504.0 MB 117 kB/s eta 0:01:06
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (45.2.0)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 60 kB/s  eta 0:00:01
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 434 kB/s eta 0:00:01
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 486 kB/s eta 0:00:01 714 kB/s eta 0:00:03
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      |████████████████████████████████| 81 kB 540 kB/s eta 0:00:01
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 25 kB/s  eta 0:00:01|█████▊                          | 2.5 MB 462 kB/s eta 0:00:25
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 32 kB/s  eta 0:00:01
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 724 kB/s eta 0:00:01
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 17 kB/s  eta 0:00:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 1.3 kB/s eta 0:00:01
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 815 kB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/nihar/.local/lib/python3.8/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.14.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.47.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 365 kB/s eta 0:00:01
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 16 kB/s  eta 0:00:011
# Requirement already satisfied: numpy>=1.20 in /home/nihar/.local/lib/python3.8/site-packages (from tensorflow) (1.23.2)
# Requirement already satisfied: packaging in /home/nihar/.local/lib/python3.8/site-packages (from tensorflow) (21.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 6.0 MB/s eta 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 4.3 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 931 kB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.34.2)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 272 kB/s eta 0:00:011
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.10.0-py2.py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /home/nihar/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/nihar/.local/lib/python3.8/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/nihar/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nihar/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /home/nihar/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/nihar/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 2.5 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/nihar/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.25.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/nihar/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/nihar/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.8.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 513 kB/s eta 0:00:011
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=831dbec7de17b93bdff55d458976145bf4586d62ad980809eed601747369533a
#   Stored in directory: /home/nihar/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: termcolor, tensorflow-estimator, flatbuffers, opt-einsum, protobuf, pyasn1, pyasn1-modules, rsa, google-auth, google-auth-oauthlib, tensorboard-plugin-wit, absl-py, werkzeug, tensorboard-data-server, markdown, grpcio, tensorboard, astunparse, wrapt, libclang, tensorflow-io-gcs-filesystem, keras, gast, google-pasta, h5py, keras-preprocessing, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
# Successfully installed absl-py-1.2.0 astunparse-1.6.3 flatbuffers-1.12 gast-0.4.0 google-auth-2.10.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 h5py-3.7.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.9 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0 werkzeug-2.2.2 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/nihar/Documents/ML/Live_Tweets_py.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/nihar/Documents/ML/Live_Tweets_py.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> classifier = pipeline('sentiment-analysis')
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/__init__.py:650, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     646 # Infer the framework from the model
#     647 # Forced if framework already defined, inferred if it's None
#     648 # Will load the correct model if possible
#     649 model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 650 framework, model = infer_framework_load_model(
#     651     model,
#     652     model_classes=model_classes,
#     653     config=config,
#     654     framework=framework,
#     655     task=task,
#     656     **hub_kwargs,
#     657     **model_kwargs,
#     658 )
#     660 model_config = model.config
#     662 load_tokenizer = type(model_config) in TOKENIZER_MAPPING or model_config.tokenizer_class is not None
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:209, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     183 """
#     184 Select framework (TensorFlow or PyTorch) to use from the `model` passed. Returns a tuple (framework, model).
#     185
#    (...)
#     206     `Tuple`: A tuple framework, model.
#     207 """
#     208 if not is_tf_available() and not is_torch_available():
# --> 209     raise RuntimeError(
#     210         "At least one of TensorFlow 2.0 or PyTorch should be installed. "
#     211         "To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ "
#     212         "To install PyTorch, read the instructions at https://pytorch.org/."
#     213     )
#     214 if isinstance(model, str):
#     215     model_kwargs["_from_pipeline"] = task
#
# RuntimeError: At least one of TensorFlow 2.0 or PyTorch should be installed. To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ To install PyTorch, read the instructions at https://pytorch.org/.

# %% [markdown]
# Give name to app using streamlit

# %%
st.title('Tweets sentiment Analysis using Tweepy and huggingface analysis')
st.markdown('This app uses tweepy to get tweets from twitter based on the input name/phrase.It then processes the tweets through HuggingFace transformers pipeline function for sentiment analysis. The resulting sentiments and corresponding tweets are then put in a dataframe for display which is what you see as result.')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
def run():
  with st.form(key='Virat'):
    search_words = st.text_input('cricket')
    number_of_tweets = st.number_input('45')
    submit_button = st.form_submit_button(label='Submit')
  if submit_button:
    tweets =tw.Cursor(api.search_tweets,q=search_words,lang="en").items(number_of_tweets)
    tweet_list = [i.text for i in tweets]
    p = [i for i in classifier(tweet_list)]
    q=[p[i]['label'] for i in range(len(p))]
    df = pd.DataFrame(list(zip(tweet_list, q)),columns =['Latest'+str(number_of_tweets)+'Tweets'+'on'+search_words, 'sentiment'])
    st.write(df)
 

if __name__=='__main__':
  run()
